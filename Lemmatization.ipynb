# %% [markdown]
# <a href="https://colab.research.google.com/github/Saransh-Basu-01/Natural-Language-Processing-NLP-/blob/main/Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk
from nltk.stem import WordNetLemmatizer
short_stemming_sample = """
The runners were running quickly. They had run many miles.
The leaves were falling gently. The fallen leaves covered the ground.
The children played games. Their playing continued until dark.
The teacher taught history. She had taught the same lesson.
The students learned quickly. Their learning never stopped.
The fisherman caught fish. He had fished for years.
The birds were flying high. They flew over the mountains.
The flowers bloomed in spring. They had bloomed every year.
The cars drove fast. Their driving was excellent.
The workers worked hard. They had worked for decades.
The water flowed down the river. It had flowed for centuries.
The sun shone brightly. It had shined on this land forever.
"""
wordnet_lemma=WordNetLemmatizer()
sentence_words=nltk.word_tokenize(short_stemming_sample)
punctuation="?:!..,;"

for word in sentence_words:
  if word in punctuation:
    sentence_words.remove(word)
sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
  print("{0:20}{1:20}".format(word,wordnet_lemma.lemmatize(word,pos='v')))
# Out:
# Word                Lemma
# The                 The
# runners             runners
# were                be
# running             run
# quickly             quickly
# They                They
# had                 have
# run                 run
# many                many
# miles               miles
# The                 The
# leaves              leave
# were                be
# falling             fall
# gently              gently
# The                 The
# fallen              fall
# leaves              leave
# covered             cover
# the                 the
# ground              grind
# The                 The
# children            children
# played              play
# games               game
# Their               Their
# playing             play
# continued           continue
# until               until
# dark                dark
# The                 The
# teacher             teacher
# taught              teach
# history             history
# She                 She
# ...
