# %% [markdown]
# <a href="https://colab.research.google.com/github/Saransh-Basu-01/Natural-Language-Processing-NLP-/blob/main/Bag__of_Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({'text':['people watch campusx','campusx watch campusx','people write comment','campusx write comment'],'labels':[1,1,0,0]})

# %%
df
# Out:
#                     text  labels
# 0   people watch campusx       1
# 1  campusx watch campusx       1
# 2   people write comment       0
# 3  campusx write comment       0

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer()

# %%
bow=cv.fit_transform(df['text'])

# %%
cv.vocabulary_
# Out:
# {'people': 2, 'watch': 3, 'campusx': 0, 'write': 4, 'comment': 1}

# %%
bow[0].toarray()
# Out:
# array([[1, 0, 1, 1, 0]])

# %%
cv.transform(['Helo campusx watch write campusx people helo helo']).toarray()
# Out:
# array([[2, 0, 1, 1, 1]])
