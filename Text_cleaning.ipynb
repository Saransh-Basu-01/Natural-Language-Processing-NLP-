# %% [markdown]
# <a href="https://colab.research.google.com/github/Saransh-Basu-01/Natural-Language-Processing-NLP-/blob/main/Text_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Removing HTML Tags

# %%
sample_text = '<html><head><title>Sample HTML Document</title><meta charset="UTF-8"><style>body { font-family: Arial, sans-serif; }.highlight { background-color: yellow; }</style></head><body><h1>Welcome to My Sample Page</h1><h2>Hello my name is John Doe</h2><h3>And this is a sample document</h3><p>This is a <strong>paragraph</strong> with <em>various</em> <u>formatting</u> tags.</p><div class="container"><p>Here\'s a list of items:</p><ul><li>First item with <a href="https://example.com">a link</a></li><li>Second item with <span class="highlight">highlighted text</span></li><li>Third item with <b>bold</b> and <i>italic</i> text</li></ul></div><table border="1"><tr><th>Name</th><th>Age</th><th>City</th></tr><tr><td>Alice</td><td>25</td><td>New York</td></tr><tr><td>Bob</td><td>30</td><td>London</td></tr></table><p>Here\'s a <a href="#" onclick="alert(\'Hello!\')">link with JavaScript</a>.</p><img src="image.jpg" alt="Sample image" width="200" height="150"><blockquote>This is a blockquote with some <cite>citation</cite> text.</blockquote><p>Some inline tags: <code>code</code>, <sub>subscript</sub>, <sup>superscript</sup>, <mark>marked text</mark>, and <small>small text</small>.</p><form action="/submit" method="POST"><label for="name">Name:</label><input type="text" id="name" name="name" value="John"><br><label for="email">Email:</label><input type="email" id="email" name="email" value="john@example.com"><br><input type="submit" value="Submit"></form><footer><p>&copy; 2024 My Company. All rights reserved.</p></footer></body></html>'

# %%
sample_text
# Out:
# '<html><head><title>Sample HTML Document</title><meta charset="UTF-8"><style>body { font-family: Arial, sans-serif; }.highlight { background-color: yellow; }</style></head><body><h1>Welcome to My Sample Page</h1><h2>Hello my name is John Doe</h2><h3>And this is a sample document</h3><p>This is a <strong>paragraph</strong> with <em>various</em> <u>formatting</u> tags.</p><div class="container"><p>Here\'s a list of items:</p><ul><li>First item with <a href="https://example.com">a link</a></li><li>Second item with <span class="highlight">highlighted text</span></li><li>Third item with <b>bold</b> and <i>italic</i> text</li></ul></div><table border="1"><tr><th>Name</th><th>Age</th><th>City</th></tr><tr><td>Alice</td><td>25</td><td>New York</td></tr><tr><td>Bob</td><td>30</td><td>London</td></tr></table><p>Here\'s a <a href="#" onclick="alert(\'Hello!\')">link with JavaScript</a>.</p><img src="image.jpg" alt="Sample image" width="200" height="150"><blockquote>This is a blockquote with som
# ...

# %%
import re
def striphtml(text):
    p = re.compile(r'<.*?>')
    return p.sub('', text)

    #sub is substitute

# %%
striphtml(sample_text)
# Out:
# "Sample HTML Documentbody { font-family: Arial, sans-serif; }.highlight { background-color: yellow; }Welcome to My Sample PageHello my name is John DoeAnd this is a sample documentThis is a paragraph with various formatting tags.Here's a list of items:First item with a linkSecond item with highlighted textThird item with bold and italic textNameAgeCityAlice25New YorkBob30LondonHere's a link with JavaScript.This is a blockquote with some citation text.Some inline tags: code, subscript, superscript, marked text, and small text.Name:Email:&copy; 2024 My Company. All rights reserved."

# %% [markdown]
# # Unicode Normalization

# %%
sample_text_with_emojis = '<html><head><title>🎉 Emoji Sample Page 🎊</title></head><body><h1>👋 Welcome to My Emoji Page! 🌟</h1><h2>Hello my name is John Doe 😊👋</h2><h3>And this is a sample document with emojis 📄✨</h3><p>This is a <strong>paragraph</strong> with <em>various</em> <u>formatting</u> tags and emojis! 🎨🖌️</p><div class="container"><p>Here\'s a list of items with emojis: 🛒</p><ul><li>🍎 First item with <a href="https://example.com">a link</a> 🔗</li><li>⭐ Second item with <span class="highlight">highlighted text</span> ✨</li><li>🚀 Third item with <b>bold</b> and <i>italic</i> text 💫</li></ul></div><table border="1"><tr><th>📛 Name</th><th>🔢 Age</th><th>🌍 City</th></tr><tr><td>👩 Alice</td><td>2️⃣5️⃣</td><td>🗽 New York</td></tr><tr><td>👨 Bob</td><td>3️⃣0️⃣</td><td>🏰 London</td></tr></table><p>Here\'s a <a href="#" onclick="alert(\'Hello! 👋\')">link with JavaScript</a> and emojis! 💻</p><img src="image.jpg" alt="Sample image 🖼️" width="200" height="150"><blockquote>💬 This is a blockquote with some <cite>citation</cite> text and emojis! 📝</blockquote><p>Some inline tags: <code>code</code> 💻, <sub>subscript</sub> 🔽, <sup>superscript</sup> 🔼, <mark>marked text</mark> 🟡, and <small>small text</small> 🔹.</p><p>Here are some more emojis to test: 😀😁😂🤣😃😄😅😆😉😊😋😎😍🥰😘😗😙😚☺️🙂🤗🤩🤔🤨😐😑😶🙄😏😣😥😮🤐😯😪😫😴😌😛😜😝🤤😒😓😔😕🙃🤑😲☹️🙁😖😞😟😤😢😭😦😧😨😩🤯😬😰😱🥵🥶😳🤪😵😡😠🤬</p><form action="/submit" method="POST"><label for="name">📝 Name:</label><input type="text" id="name" name="name" value="John"><br><label for="email">📧 Email:</label><input type="email" id="email" name="email" value="john@example.com"><br><input type="submit" value="✅ Submit"></form><footer><p>© 2024 My Company 🏢. All rights reserved. Made with ❤️</p></footer></body></html>'

# %%
import re
def striphtmlemoji(text):
    p = re.compile(r'<.*?>')
    return p.sub('', text)

# %%
text=striphtmlemoji(sample_text_with_emojis)

# %%
text.encode('utf-8')
# Out:
# b"\xf0\x9f\x8e\x89 Emoji Sample Page \xf0\x9f\x8e\x8a\xf0\x9f\x91\x8b Welcome to My Emoji Page! \xf0\x9f\x8c\x9fHello my name is John Doe \xf0\x9f\x98\x8a\xf0\x9f\x91\x8bAnd this is a sample document with emojis \xf0\x9f\x93\x84\xe2\x9c\xa8This is a paragraph with various formatting tags and emojis! \xf0\x9f\x8e\xa8\xf0\x9f\x96\x8c\xef\xb8\x8fHere's a list of items with emojis: \xf0\x9f\x9b\x92\xf0\x9f\x8d\x8e First item with a link \xf0\x9f\x94\x97\xe2\xad\x90 Second item with highlighted text \xe2\x9c\xa8\xf0\x9f\x9a\x80 Third item with bold and italic text \xf0\x9f\x92\xab\xf0\x9f\x93\x9b Name\xf0\x9f\x94\xa2 Age\xf0\x9f\x8c\x8d City\xf0\x9f\x91\xa9 Alice2\xef\xb8\x8f\xe2\x83\xa35\xef\xb8\x8f\xe2\x83\xa3\xf0\x9f\x97\xbd New York\xf0\x9f\x91\xa8 Bob3\xef\xb8\x8f\xe2\x83\xa30\xef\xb8\x8f\xe2\x83\xa3\xf0\x9f\x8f\xb0 LondonHere's a link with JavaScript and emojis! \xf0\x9f\x92\xbb\xf0\x9f\x92\xac This is a blockquote with some citation text and emojis! \xf0\x9f\x93\x9dSome inline tags
# ...

# %% [markdown]
# # spelling checker

# %%
spelling_sample = """
<h1>Welcom to my Homepage</h1>
<p>My name is Jhon Doe and I am a sofware engineer.</p>
<p>I have experiance in programing languages like Python, Java, and C++.</p>
<p>I am currently studing at the univercity and working on a projct.</p>
<ul>
    <li>I enjoy reading books about sience and tecnology</li>
    <li>My favorite food is pizza and pasta</li>
    <li>I like to traval to new places</li>
</ul>
<p>Tommorrow I have an importent meeting with my team.</p>
<p>We need to disscuss the new features for our aplication.</p>
<p>I think we should focuss on user experiance and perfomance.</p>
<p>The currant situation is chalenging but we are making progess.</p>
<p>Please let me no if you have any questons.</p>
<p>Your opnion is valuble to us.</p>
<p>I will be avalible for the call at 3pm.</p>
<p>This is a sentance with alot of spelling mistakes.</p>
<p>I am responsable for the project delivary.</p>
<p>The team is working collabortively to achive the goals.</p>
"""

# %%
def striphtml2(text):
  p=re.compile('<.*?>')
  return p.sub('',text)

# %%
p=striphtml2(spelling_sample)

# %%
p
# Out:
# '\nWelcom to my Homepage\nMy name is Jhon Doe and I am a sofware engineer.\nI have experiance in programing languages like Python, Java, and C++.\nI am currently studing at the univercity and working on a projct.\n\n    I enjoy reading books about sience and tecnology\n    My favorite food is pizza and pasta\n    I like to traval to new places\n\nTommorrow I have an importent meeting with my team.\nWe need to disscuss the new features for our aplication.\nI think we should focuss on user experiance and perfomance.\nThe currant situation is chalenging but we are making progess.\nPlease let me no if you have any questons.\nYour opnion is valuble to us.\nI will be avalible for the call at 3pm.\nThis is a sentance with alot of spelling mistakes.\nI am responsable for the project delivary.\nThe team is working collabortively to achive the goals.\n'

# %%
from textblob import TextBlob
textblb=TextBlob(p)
textblb.correct()
# Out:
# TextBlob("
# Seldom to my Homepage
# By name is Hon Toe and I am a software engineer.
# I have experience in programming languages like Python, Cava, and C++.
# I am currently studying at the university and working on a project.
#
#     I enjoy reading books about since and technology
#     By favorite food is penza and past
#     I like to travel to new places
#
# Tomorrow I have an important meeting with my team.
# He need to discuss the new features for our application.
# I think we should focus on user experience and performance.
# The current situation is challenging but we are making process.
# Please let me no if you have any questions.
# Your opinion is valuable to us.
# I will be available for the call at pm.
# His is a sentence with clot of spelling mistakes.
# I am responsible for the project delivery.
# The team is working collabortively to active the goals.
# ")

# %%
textblb=TextBlob(spelling_sample)
textblb.correct()
# Out:
# TextBlob("
# <he>Seldom to my Homepage</he>
# <p>By name is Hon Toe and I am a software engineer.</p>
# <p>I have experience in programming languages like Python, Cava, and C++.</p>
# <p>I am currently studying at the university and working on a project.</p>
# <up>
#     <li>I enjoy reading books about since and technology</li>
#     <li>By favorite food is penza and past</li>
#     <li>I like to travel to new places</li>
# </up>
# <p>Tomorrow I have an important meeting with my team.</p>
# <p>He need to discuss the new features for our application.</p>
# <p>I think we should focus on user experience and performance.</p>
# <p>The current situation is challenging but we are making process.</p>
# <p>Please let me no if you have any questions.</p>
# <p>Your opinion is valuable to us.</p>
# <p>I will be available for the call at pm.</p>
# <p>His is a sentence with clot of spelling mistakes.</p>
# <p>I am responsible for the project delivery.</p>
# ...

# %% [markdown]
# # Tokenizattion

# %% [markdown]
# ## using nltk library

# %%
normal_text = """
Welcom to my website. My name is Jhon and I am a studnt at the univercity.
I am lerning to code in Python and Java. Tommorrow I have a exam and I am very nervus.
I need to study more for the test becuase its importent. My freind told me about this great oportunity.
I hope I will pas the exam with good marks. I am also working on a projct with my team.
We are trying to improve the perfomance of our aplication. This is a chalenging task but we are making progess.
I think we should focuss on user experiance. Please let me no if you have any questons.
Your opnion is valuble to us. I am responsable for the project delivary.
The team is working collabortively to achive the goals. I have experiance in programing.
I enjoy reading about sience and tecnology. My favorite food is pizza and pasta.
I also like to traval to new places. The currant situation is difficult but we are managing.
"""

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sents=sent_tokenize(normal_text)
sents
# Out:
# ['\nWelcom to my website.',
#  'My name is Jhon and I am a studnt at the univercity.',
#  'I am lerning to code in Python and Java.',
#  'Tommorrow I have a exam and I am very nervus.',
#  'I need to study more for the test becuase its importent.',
#  'My freind told me about this great oportunity.',
#  'I hope I will pas the exam with good marks.',
#  'I am also working on a projct with my team.',
#  'We are trying to improve the perfomance of our aplication.',
#  'This is a chalenging task but we are making progess.',
#  'I think we should focuss on user experiance.',
#  'Please let me no if you have any questons.',
#  'Your opnion is valuble to us.',
#  'I am responsable for the project delivary.',
#  'The team is working collabortively to achive the goals.',
#  'I have experiance in programing.',
#  'I enjoy reading about sience and tecnology.',
#  'My favorite food is pizza and pasta.',
#  'I also like to traval to new places.',
# ...

# %%
words=word_tokenize(normal_text)
words
# Out:
# ['Welcom',
#  'to',
#  'my',
#  'website',
#  '.',
#  'My',
#  'name',
#  'is',
#  'Jhon',
#  'and',
#  'I',
#  'am',
#  'a',
#  'studnt',
#  'at',
#  'the',
#  'univercity',
#  '.',
#  'I',
#  'am',
#  'lerning',
#  'to',
#  'code',
#  'in',
#  'Python',
#  'and',
#  'Java',
#  '.',
#  'Tommorrow',
#  'I',
#  'have',
#  'a',
#  'exam',
#  'and',
#  'I',
#  'am',
#  'very',
#  'nervus',
#  '.',
#  'I',
#  'need',
#  'to',
#  'study',
#  'more',
#  'for',
#  'the',
#  'test',
#  'becuase',
#  'its',
#  'importent',
#  '.',
#  'My',
#  'freind',
#  'told',
#  'me',
#  'about',
#  'this',
#  'great',
#  'oportunity',
#  '.',
#  'I',
#  'hope',
#  'I',
#  'will',
#  'pas',
#  'the',
#  'exam',
#  'with',
#  'good',
#  'marks',
#  '.',
#  'I',
#  'am',
#  'also',
#  'working',
#  'on',
#  'a',
#  'projct',
#  'with',
#  'my',
#  'team',
#  '.',
#  'We',
#  'are',
#  'trying',
#  'to',
#  'improve',
#  'the',
#  'perfomance',
#  'of',
#  'our',
#  'aplication',
#  '.',
#  'This',
#  'is',
# ...

# %%
for sent in sents:
  print(word_tokenize(sent))
# Out:
# ['Welcom', 'to', 'my', 'website', '.']
# ['My', 'name', 'is', 'Jhon', 'and', 'I', 'am', 'a', 'studnt', 'at', 'the', 'univercity', '.']
# ['I', 'am', 'lerning', 'to', 'code', 'in', 'Python', 'and', 'Java', '.']
# ['Tommorrow', 'I', 'have', 'a', 'exam', 'and', 'I', 'am', 'very', 'nervus', '.']
# ['I', 'need', 'to', 'study', 'more', 'for', 'the', 'test', 'becuase', 'its', 'importent', '.']
# ['My', 'freind', 'told', 'me', 'about', 'this', 'great', 'oportunity', '.']
# ['I', 'hope', 'I', 'will', 'pas', 'the', 'exam', 'with', 'good', 'marks', '.']
# ['I', 'am', 'also', 'working', 'on', 'a', 'projct', 'with', 'my', 'team', '.']
# ['We', 'are', 'trying', 'to', 'improve', 'the', 'perfomance', 'of', 'our', 'aplication', '.']
# ['This', 'is', 'a', 'chalenging', 'task', 'but', 'we', 'are', 'making', 'progess', '.']
# ['I', 'think', 'we', 'should', 'focuss', 'on', 'user', 'experiance', '.']
# ['Please', 'let', 'me', 'no', 'if', 'you', 'have', 'any', 'questons', '.']
# ...

# %% [markdown]
# ## using manual code why manuall ramailo xaa ni

# %%
def word_token(text):
  return text.split(" ")
word_token(normal_text)
# Out:
# ['\nWelcom',
#  'to',
#  'my',
#  'website.',
#  'My',
#  'name',
#  'is',
#  'Jhon',
#  'and',
#  'I',
#  'am',
#  'a',
#  'studnt',
#  'at',
#  'the',
#  'univercity.',
#  '\nI',
#  'am',
#  'lerning',
#  'to',
#  'code',
#  'in',
#  'Python',
#  'and',
#  'Java.',
#  'Tommorrow',
#  'I',
#  'have',
#  'a',
#  'exam',
#  'and',
#  'I',
#  'am',
#  'very',
#  'nervus.\nI',
#  'need',
#  'to',
#  'study',
#  'more',
#  'for',
#  'the',
#  'test',
#  'becuase',
#  'its',
#  'importent.',
#  'My',
#  'freind',
#  'told',
#  'me',
#  'about',
#  'this',
#  'great',
#  'oportunity.\nI',
#  'hope',
#  'I',
#  'will',
#  'pas',
#  'the',
#  'exam',
#  'with',
#  'good',
#  'marks.',
#  'I',
#  'am',
#  'also',
#  'working',
#  'on',
#  'a',
#  'projct',
#  'with',
#  'my',
#  'team.\nWe',
#  'are',
#  'trying',
#  'to',
#  'improve',
#  'the',
#  'perfomance',
#  'of',
#  'our',
#  'aplication.',
#  'This',
#  'is',
#  'a',
#  'chalenging',
#  'task',
#  'but',
#  'we',
#  'are',
# ...

# %%
def sentence_token(text):
  text = text.replace('\n', ' ')
  text = (text.split("."))
  return text
sentence_token(normal_text)
# Out:
# [' Welcom to my website',
#  ' My name is Jhon and I am a studnt at the univercity',
#  '  I am lerning to code in Python and Java',
#  ' Tommorrow I have a exam and I am very nervus',
#  ' I need to study more for the test becuase its importent',
#  ' My freind told me about this great oportunity',
#  ' I hope I will pas the exam with good marks',
#  ' I am also working on a projct with my team',
#  ' We are trying to improve the perfomance of our aplication',
#  ' This is a chalenging task but we are making progess',
#  ' I think we should focuss on user experiance',
#  ' Please let me no if you have any questons',
#  ' Your opnion is valuble to us',
#  ' I am responsable for the project delivary',
#  ' The team is working collabortively to achive the goals',
#  ' I have experiance in programing',
#  ' I enjoy reading about sience and tecnology',
#  ' My favorite food is pizza and pasta',
#  ' I also like to traval to new places',
# ...
