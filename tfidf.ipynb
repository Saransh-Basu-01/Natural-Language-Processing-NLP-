# %% [markdown]
# <a href="https://colab.research.google.com/github/Saransh-Basu-01/Natural-Language-Processing-NLP-/blob/main/tfidf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({'text':['people watch campusx','campusx watch campusx','people write comment','campusx write comment'],'labels':[1,1,0,0]})

# %%
df
# Out:
#                     text  labels
# 0   people watch campusx       1
# 1  campusx watch campusx       1
# 2   people write comment       0
# 3  campusx write comment       0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer()

# %%
tf=tfidf.fit_transform(df['text'])

# %%
tfidf.vocabulary_
# Out:
# {'people': 2, 'watch': 3, 'campusx': 0, 'write': 4, 'comment': 1}

# %%
tf[0].toarray()
# Out:
# array([[0.49681612, 0.        , 0.61366674, 0.61366674, 0.        ]])

# %%
tfidf.transform(['Helo campusx watch write campusx people helo helo']).toarray()
# Out:
# array([[0.6829022 , 0.        , 0.42176004, 0.42176004, 0.42176004]])

# %%
tfidf.fit_transform(df['text']).toarray()
# Out:
# array([[0.49681612, 0.        , 0.61366674, 0.61366674, 0.        ],
#        [0.8508161 , 0.        , 0.        , 0.52546357, 0.        ],
#        [0.        , 0.57735027, 0.57735027, 0.        , 0.57735027],
#        [0.49681612, 0.61366674, 0.        , 0.        , 0.61366674]])
